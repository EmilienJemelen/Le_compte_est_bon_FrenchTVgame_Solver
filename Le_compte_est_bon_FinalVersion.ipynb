# %%
#FIRST VERSION: quicker but incomplete version. Does not do operations like a/(c+d) or (a+b)*(c+d) or (a*b)+(c*d) etc.

n=int(input('How many integers do you want to use? NB: more than 6 can take a long period of time')) 

import random
from random import randint

def random_draw() :
    set1 = [k for k in range(1,11)]
    set2 = [25*k for k in range(1,5)]
    data = set1 + set1 + set2 + set2
    random.shuffle(data)
    return data[0:n]

target_number = randint(100,999)
draw = random_draw()


print('We can use',draw)
print('We want :',target_number)
print(' ')

class Node :
    def __init__(self, value, available, children = [], ancester=[]) :
        self.value = value
        self.available = available
        self.children = children
        self.ancester = ancester

class Tree:
    def __init__(self,available=draw):
        build_children(Node(0,available))
        self.tree = Node(0,available)
      

    
def ancesters(node):
    genealogy = [node]
    if node.ancester is not None:
        daddy = node.ancester
    while daddy.value != 0:
        genealogy.append(daddy)
        daddy=daddy.ancester
    return genealogy[::-1]

def build_children(node) :
    if node.available == [0 for i in range(len(node.available))] :
        return 
    for k in range(len(node.available)) :
        if node.available[k] != 0 :
            copy = node.available.copy()
            copy[k] = 0
            node.children.append(Node(node.value + node.available[k], copy, [], node))    
            if node.value != 0:
                node.children.append(Node(node.value * node.available[k], copy, [], node))
            if node.value-node.available[k] > 0 :
                node.children.append(Node(node.value - node.available[k], copy, [], node))
            div = node.value / node.available[k]
            if div == int(div) and div >1:
                node.children.append(Node(node.value / node.available[k], copy, [], node))
    for children in node.children:
        build_children(children)

Q=Tree()


def find_target(node,target,lengths=[],paths=[], values_knowledge = []):
    if node is None:
        return
    if node.value == target:
        ancesters_values = [ancester.value for ancester in ancesters(node)[1:]]
        if set(ancesters_values) not in values_knowledge :
            values_knowledge.append(set(ancesters_values))
            paths.append(ancesters(node))
            lengths.append(len(ancesters(node)))
    for children in node.children :
        find_target(children,target, lengths, paths, values_knowledge)
    return lengths, paths

[lengths, paths] = find_target(Q.tree, target_number)


def shortest_paths(lengths, paths):
    positions=[]
    if len(lengths)>0:
        m=min(lengths)
        for k in range(len(lengths)):
            if lengths[k]==m:
                positions.append(k)
    return [paths[i] for i in positions]

shortest_paths = shortest_paths(lengths,paths)

def missing_coordinate(vector1,vector2):
    for k in range(len(vector1)):
        if vector1[k] != vector2[k]:
            return vector1[k]

def path_clarifier(path, target_number):
    n=len(path)
    for j in range(n-1):
        used_number = missing_coordinate(path[j].available, path[j+1].available)
        if path[j+1].value == path[j].value + used_number:
            print(path[j].value,'+',used_number,'=',path[j+1].value)
        if path[j+1].value == path[j].value - used_number:
            print(path[j].value,'-',used_number,'=',path[j+1].value)
        if path[j+1].value == path[j].value * used_number:
            print(path[j].value,'x',used_number,'=',path[j+1].value)
        if path[j+1].value == path[j].value / used_number:
            print(path[j].value,'/',used_number,'=',path[j+1].value)




if paths == []:
    print('THERE ARE NO SOLUTION')
else:
    print('THE OPTIMAL SOLUTIONS ARE :')
    for path in shortest_paths:
        path_clarifier(path,target_number)
        print('----')
    
    print('THE SOLUTIONS ARE:')
    for path in paths:
        path_clarifier(path,target_number)
        print('----')
# Out:
# How many integers do you want to use? NB: more than 6 can take a long period of time6
# We can use [75, 2, 7, 6, 4, 8]
# We want : 379
#
# THE OPTIMAL SOLUTIONS ARE :
# 7 - 2 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# THE SOLUTIONS ARE:
# 75 - 2 = 73
# 73 - 8 = 65
# 65 x 6 = 390
# 390 - 7 = 383
# 383 - 4 = 379
# ----
# 75 - 2 = 73
# 73 - 8 = 65
# 65 x 6 = 390
# 390 - 4 = 386
# 386 - 7 = 379
# ----
# 75 - 8 = 67
# 67 - 2 = 65
# 65 x 6 = 390
# 390 - 7 = 383
# 383 - 4 = 379
# ----
# 75 - 8 = 67
# 67 - 2 = 65
# 65 x 6 = 390
# 390 - 4 = 386
# 386 - 7 = 379
# ----
# 2 x 7 = 14
# 14 x 6 = 84
# 84 - 8 = 76
# 76 x 4 = 304
# 304 + 75 = 379
# ----
# 2 x 7 = 14
# 14 x 4 = 56
# 56 x 8 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 7 = 14
# 14 x 4 = 56
# 56 x 8 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 2 x 7 = 14
# 14 x 8 = 112
# 112 x 4 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 7 = 14
# 14 x 8 = 112
# 112 x 4 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 2 x 6 = 12
# 12 x 7 = 84
# 84 - 8 = 76
# 76 x 4 = 304
# 304 + 75 = 379
# ----
# 2 x 6 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 2 x 6 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 - 4 = 371
# 371 + 8 = 379
# ----
# 2 x 6 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 8 = 383
# 383 - 4 = 379
# ----
# 2 x 4 = 8
# 8 x 7 = 56
# 56 x 8 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 4 = 8
# 8 x 7 = 56
# 56 x 8 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 2 x 4 = 8
# 8 x 8 = 64
# 64 x 7 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 4 = 8
# 8 x 8 = 64
# 64 x 7 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 2 + 8 = 10
# 10 x 7 = 70
# 70 + 6 = 76
# 76 x 4 = 304
# 304 + 75 = 379
# ----
# 2 x 8 = 16
# 16 x 7 = 112
# 112 x 4 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 8 = 16
# 16 x 7 = 112
# 112 x 4 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 2 x 8 = 16
# 16 x 4 = 64
# 64 x 7 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 2 x 8 = 16
# 16 x 4 = 64
# 64 x 7 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 7 - 2 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 7 - 2 = 5
# 5 x 75 = 375
# 375 - 4 = 371
# 371 + 8 = 379
# ----
# 7 - 2 = 5
# 5 x 75 = 375
# 375 + 8 = 383
# 383 - 4 = 379
# ----
# 7 + 6 = 13
# 13 - 8 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 7 x 6 = 42
# 42 x 2 = 84
# 84 - 8 = 76
# 76 x 4 = 304
# 304 + 75 = 379
# ----
# 7 x 6 = 42
# 42 - 2 = 40
# 40 x 75 = 3000
# 3000 / 8 = 375.0
# 375.0 + 4 = 379.0
# ----
# 7 x 6 = 42
# 42 - 2 = 40
# 40 / 8 = 5.0
# 5.0 x 75 = 375.0
# 375.0 + 4 = 379.0
# ----
# 7 x 6 = 42
# 42 - 4 = 38
# 38 x 8 = 304
# 304 + 75 = 379
# ----
# 7 x 4 = 28
# 28 x 2 = 56
# 56 x 8 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 7 x 4 = 28
# 28 x 2 = 56
# 56 x 8 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 7 x 4 = 28
# 28 x 8 = 224
# 224 x 2 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 7 x 4 = 28
# 28 x 8 = 224
# 224 x 2 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 7 + 8 = 15
# 15 x 75 = 1125
# 1125 x 2 = 2250
# 2250 / 6 = 375.0
# 375.0 + 4 = 379.0
# ----
# 7 + 8 = 15
# 15 x 2 = 30
# 30 x 75 = 2250
# 2250 / 6 = 375.0
# 375.0 + 4 = 379.0
# ----
# 7 + 8 = 15
# 15 x 2 = 30
# 30 / 6 = 5.0
# 5.0 x 75 = 375.0
# 375.0 + 4 = 379.0
# ----
# 7 x 8 = 56
# 56 x 2 = 112
# 112 x 4 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 7 x 8 = 56
# 56 x 2 = 112
# 112 x 4 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 7 x 8 = 56
# 56 x 4 = 224
# 224 x 2 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 7 x 8 = 56
# 56 x 4 = 224
# 224 x 2 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 6 - 2 = 4
# 4 + 8 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 6 + 4 = 10
# 10 x 75 = 750
# 750 + 8 = 758
# 758 / 2 = 379.0
# ----
# 6 + 8 = 14
# 14 - 2 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 6 + 8 = 14
# 14 - 7 = 7
# 7 - 2 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 4 + 8 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 - 2 = 373
# 373 + 6 = 379
# ----
# 4 + 8 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 6 = 381
# 381 - 2 = 379
# ----
# 4 x 8 = 32
# 32 x 2 = 64
# 64 x 7 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 4 x 8 = 32
# 32 x 2 = 64
# 64 x 7 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 4 x 8 = 32
# 32 x 7 = 224
# 224 x 2 = 448
# 448 - 75 = 373
# 373 + 6 = 379
# ----
# 4 x 8 = 32
# 32 x 7 = 224
# 224 x 2 = 448
# 448 + 6 = 454
# 454 - 75 = 379
# ----
# 8 - 2 = 6
# 6 + 6 = 12
# 12 - 7 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 8 / 2 = 4.0
# 4.0 + 7 = 11.0
# 11.0 - 6 = 5.0
# 5.0 x 75 = 375.0
# 375.0 + 4 = 379.0
# ----
# 8 - 7 = 1
# 1 + 6 = 7
# 7 - 2 = 5
# 5 x 75 = 375
# 375 + 4 = 379
# ----
# 8 - 7 = 1
# 1 + 4 = 5
# 5 x 75 = 375
# 375 - 2 = 373
# 373 + 6 = 379
# ----
# 8 - 7 = 1
# 1 + 4 = 5
# 5 x 75 = 375
# 375 + 6 = 381
# 381 - 2 = 379
# ----

# %%
class Node :
    def __init__(self, memo, children = [], track = []) :
        self.memo = memo
        self.children = children
        self.track = track

class Tree :
    def __init__(self, memo = draw, target_number = target_number) :
        build_children(Node(memo), target_number)
        self.tree = Node(memo)

def build_children(node, target_number, the_Knowledge = []) :
    if len(node.memo) == 1 :
            return
    if target_number in node.memo :
        return

    length = len(node.memo)
    for k in range(length) :
        if node.memo[k] != 0 :
            for j in range(length) :
                if j != k :
                    if node.memo[j] != 0 :
                        [[copy1, track1], [copy2, track2], [copy3, track3], [copy4, track4]] = [[node.memo.copy(), node.track.copy()] for k in range(4)]
                        Sum = node.memo[k] + node.memo[j]
                        Diff = node.memo[k] - node.memo[j]
                        Prod = node.memo[k] * node.memo[j]
                        Div = node.memo[k] / node.memo[j]
                        if j != 0 :
                            if set([node.memo[k], '+', node.memo[j]]) not in the_Knowledge :    
                                copy1[k] = copy1[0]
                                copy1[j] = Sum
                                track1.append([node.memo[k], '+', node.memo[j], '=', Sum])
                                node.children.append(Node(copy1[1:], [], track1))
                                the_Knowledge += [set([node.memo[k], '+', node.memo[j]])]
                            if Diff > 0 :
                                copy2[k] = copy2[0]
                                copy2[j] = Diff
                                track2.append([node.memo[k], '-', node.memo[j], '=', Diff])
                                node.children.append(Node(copy2[1:], [], track2))
                            if set([node.memo[k], 'x', node.memo[j]]) not in the_Knowledge :    
                                copy3[k] = copy3[0]
                                copy3[j] = Prod
                                track3.append([node.memo[k], 'x', node.memo[j], '=', Prod])
                                node.children.append(Node(copy3[1:], [], track3))
                                the_Knowledge += [set([node.memo[k], 'x', node.memo[j]])]

                            if Div == int(Div) :
                                copy4[k] = copy4[0]
                                copy4[j] = Div
                                track4.append([node.memo[k], '/', node.memo[j], '=', Div])
                                node.children.append(Node(copy4[1:], [], track4))

                        if j == 0 :
                            if set([node.memo[k], '+', node.memo[j]]) not in the_Knowledge :    
                                copy1[k] = Sum
                                track1.append([node.memo[k], '+', node.memo[j], '=', Sum])
                                node.children.append(Node(copy1[1:], [], track1))
                                the_Knowledge += [set([node.memo[k], '+', node.memo[j]])]

                            if Diff > 0 :
                                copy2[k] = Diff
                                track2.append([node.memo[k], '-', node.memo[j], '=', Diff])
                                node.children.append(Node(copy2[1:], [], track2))

                            if set([node.memo[k], 'x', node.memo[j]]) not in the_Knowledge:
                                copy3[k] = Prod
                                track3.append([node.memo[k], 'x', node.memo[j], '=', Prod])
                                node.children.append(Node(copy3[1:], [], track3))
                                the_Knowledge += [set([node.memo[k], 'x', node.memo[j]])]

                            if Div == int(Div) :
                                copy4[k] = Div
                                track4.append([node.memo[k], '/', node.memo[j], '=', Div])
                                node.children.append(Node(copy4[1:], [], track4))
                                the_Knowledge += [set([node.memo[k], '/', node.memo[j]])]
                            


    for children in node.children :
        build_children(children, target_number, the_Knowledge=[])

T = Tree()

# %%
#GLOBAL SEARCH
                        
print('We can use:',draw)
print(' ')
print('We want :',target_number)
print(' ')

print('THE SOLUTIONS ARE')
def find_target(target, node):
    if node is None :
        return
    if target in node.memo :
        print(node.track)
    for children in node.children :
        find_target(target, children)

find_target(target_number, T.tree)
# Out:
# We can use: [75, 2, 7, 6, 4, 8]
#
# We want : 379
#
# THE SOLUTIONS ARE
# [[75, '+', 2, '=', 77], [7, '-', 4, '=', 3], [8, '-', 3, '=', 5], [5, 'x', 77, '=', 385], [385, '-', 6, '=', 379]]
# [[75, '+', 2, '=', 77], [6, 'x', 4, '=', 24], [77, '-', 24, '=', 53], [7, 'x', 53, '=', 371], [371, '+', 8, '=', 379]]
# [[75, '+', 2, '=', 77], [4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [77, 'x', 5, '=', 385], [385, '-', 6, '=', 379]]
# [[75, '+', 2, '=', 77], [8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [5, 'x', 77, '=', 385], [385, '-', 6, '=', 379]]
# [[75, '+', 2, '=', 77], [8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 77, '=', 385.0], [385.0, '-', 6, '=', 379.0]]
# [[75, '-', 2, '=', 73], [73, '-', 8, '=', 65], [7, '+', 4, '=', 11], [6, 'x', 65, '=', 390], [390, '-', 11, '=', 379]]
# [[75, '-', 2, '=', 73], [73, '-', 8, '=', 65], [6, 'x', 65, '=', 390], [7, '+', 4, '=', 11], [390, '-', 11, '=', 379]]
# [[75, '-', 2, '=', 73], [73, '-', 8, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 7, '=', 383], [383, '-', 4, '=', 379]]
# [[75, '-', 2, '=', 73], [73, '-', 8, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 4, '=', 386], [386, '-', 7, '=', 379]]
# [[75, '-', 2, '=', 73], [7, '+', 4, '=', 11], [73, '-', 8, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 11, '=', 379]]
# [[75, 'x', 2, '=', 150], [150, '/', 6, '=', 25.0], [7, '+', 8, '=', 15], [25.0, 'x', 15, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [
[4, 'x', 112, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 7, '=', 14], [14, 'x', 8, '=', 112], [4, 'x', 112, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[2, 'x', 7, '=', 14], [14, 'x', 8, '=', 112], [4, 'x', 112, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[2, 'x', 7, '=', 14], [14, 'x', 8, '=', 112], [4, 'x', 112, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[2, 'x', 7, '=', 14], [6, 'x', 4, '=', 24], [14, '+', 24, '=', 38], [38, 'x', 8, '=', 304], [75, '+', 304, '=', 379]]
# [[2, 'x', 7, '=', 14], [4, 'x', 8, '=', 32], [14, 'x', 32, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[2, 'x', 7, '=', 14], [4, 'x', 8, '=', 32], [14, 'x', 32, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[2, 'x', 7, '=', 14], [4, 'x', 8, '=', 32], [14, 'x', 32, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[2, 'x', 7, '=', 14], [4, 'x', 8, '=', 32], [75, '-', 6, '=', 69], [14, 'x', 32, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 6, '=', 12], [7, 'x', 12, '=', 84], [84, '-', 8, '=', 76], [4, 'x', 76, '=', 304], [75, '+', 304, '=', 379]]
# [[2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [375, '+', 4, '=', 379]]
# [[2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [375, '-', 4, '=', 371], [371, '+', 8, '=', 379]]
# [[2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [375, '+', 8, '=', 383], [383, '-', 4, '=', 379]]
# [[2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [8, '-', 4, '=', 4], [4, '+', 375, '=', 379]]
# [[2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [8, '-', 4, '=', 4], [75, 'x', 5, '=', 375], [4, '+', 375, '=', 379]]
# [[2, 'x', 6, '=', 12], [8, '-', 4, '=', 4], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, '-', 6, '=', 69], [7, 'x', 8, '=', 56], [56, 'x', 8, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, '-', 6, '=', 69], [8, 'x', 8, '=', 64], [7, 'x', 64, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, 'x', 6, '=', 450], [450, '-', 7, '=', 443], [8, 'x', 8, '=', 64], [443, '-', 64, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, 'x', 6, '=', 450], [8, 'x', 8, '=', 64], [450, '-', 7, '=', 443], [443, '-', 64, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, 'x', 6, '=', 450], [8, 'x', 8, '=', 64], [450, '-', 64, '=', 386], [386, '-', 7, '=', 379]]
# [[2, 'x', 4, '=', 8], [75, 'x', 6, '=', 450], [8, 'x', 8, '=', 64], [7, '+', 64, '=', 71], [450, '-', 71, '=', 379]]
# [[2, 'x', 4, '=', 8], [7, 'x', 8, '=', 56], [75, '-', 6, '=', 69], [56, 'x', 8, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 4, '=', 8], [7, 'x', 8, '=', 56], [56, 'x', 8, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[2, 'x', 4, '=', 8], [7, 'x', 8, '=', 56], [56, 'x', 8, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[2, 'x', 4, '=', 8], [7, 'x', 8, '=', 56], [56, 'x', 8, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [7, '+', 64, '=', 71], [6, 'x', 75, '=', 450], [450, '-', 71, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [7, 'x', 64, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [7, 'x', 64, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [7, 'x', 64, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [6, 'x', 75, '=', 450], [7, '+', 64, '=', 71], [450, '-', 71, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [6, 'x', 75, '=', 450], [450, '-', 7, '=', 443], [443, '-', 64, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [6, 'x', 75, '=', 450], [450, '-', 64, '=', 386], [386, '-', 7, '=', 379]]
# [[2, 'x', 4, '=', 8], [8, 'x', 8, '=', 64], [75, '-', 6, '=', 69], [7, 'x', 64, '=', 448], [448, '-', 69, '=', 379]]
# [[2, '+', 8, '=', 10], [75, '-', 10, '=', 65], [7, '+', 4, '=', 11], [6, 'x', 65, '=', 390], [390, '-', 11, '=', 379]]
# [[2, '+', 8, '=', 10], [75, '-', 10, '=', 65], [6, 'x', 65, '=', 390], [7, '+', 4, '=', 11], [390, '-', 11, '=', 379]]
# [[2, '+', 8, '=', 10], [75, '-', 10, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 7, '=', 383], [383, '-', 4, '=', 379]]
# [[2, '+', 8, '=', 10], [75, '-', 10, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 4, '=', 386], [386, '-', 7, '=', 379]]
# [[2, '+', 8, '=', 10], [7, '+', 4, '=', 11], [75, '-', 10, '=', 65], [6, 'x', 65, '=', 390], [390, '-', 11, '=', 379]]
# [[2, '+', 8, '=', 10], [7, 'x', 10, '=', 70], [6, '+', 70, '=', 76], [4, 'x', 76, '=', 304], [75, '+', 304, '=', 379]]
# [[2, 'x', 8, '=', 16], [75, '-', 6, '=', 69], [7, 'x', 4, '=', 28], [28, 'x', 16, '=', 448], [448, '-', 69, '=', 379]]
# [[2, 'x', 8, '=', 16], [75
, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [75, 'x', 5.0, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '-', 2, '=', 4], [8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [75, 'x', 5, '=', 375], [375, '+', 4, '=', 379]]
# [[6, '-', 2, '=', 4], [8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [75, 'x', 5.0, '=', 375.0], [375.0, '+', 4, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [7, 'x', 4, '=', 28], [75, '-', 28, '=', 47], [47, 'x', 8, '=', 376], [3.0, '+', 376, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [7, '+', 8, '=', 15], [75, '/', 3.0, '=', 25.0], [25.0, 'x', 15, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [7, '+', 8, '=', 15], [75, 'x', 15, '=', 1125], [1125, '/', 3.0, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [7, '+', 8, '=', 15], [15, '/', 3.0, '=', 5.0], [75, 'x', 5.0, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [75, '/', 3.0, '=', 25.0], [7, '+', 8, '=', 15], [25.0, 'x', 15, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '/', 2, '=', 3.0], [8, '-', 3.0, '=', 5.0], [75, 'x', 5.0, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[6, '+', 4, '=', 10], [75, 'x', 10, '=', 750], [750, '+', 8, '=', 758], [758, '/', 2, '=', 379.0]]
# [[6, '-', 4, '=', 2], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [8, '/', 2, '=', 4.0], [4.0, '+', 375, '=', 379.0]]
# [[6, '-', 4, '=', 2], [7, '-', 2, '=', 5], [8, '/', 2, '=', 4.0], [75, 'x', 5, '=', 375], [4.0, '+', 375, '=', 379.0]]
# [[6, '-', 4, '=', 2], [7, '-', 2, '=', 5], [75, 'x', 5, '=', 375], [8, '/', 2, '=', 4.0], [375, '+', 4.0, '=', 379.0]]
# [[6, '-', 4, '=', 2], [7, '-', 2, '=', 5], [8, '/', 2, '=', 4.0], [75, 'x', 5, '=', 375], [375, '+', 4.0, '=', 379.0]]
# [[6, '-', 4, '=', 2], [8, '/', 2, '=', 4.0], [7, '-', 2, '=', 5], [75, 'x', 5, '=', 375], [375, '+', 4.0, '=', 379.0]]
# [[6, '-', 4, '=', 2], [8, '/', 2, '=', 4.0], [7, '-', 2, '=', 5], [75, 'x', 5, '=', 375], [4.0, '+', 375, '=', 379.0]]
# [[6, 'x', 4, '=', 24], [2, 'x', 7, '=', 14], [14, '+', 24, '=', 38], [38, 'x', 8, '=', 304], [75, '+', 304, '=', 379]]
# [[6, 'x', 4, '=', 24], [2, '+', 75, '=', 77], [77, '-', 24, '=', 53], [7, 'x', 53, '=', 371], [371, '+', 8, '=', 379]]
# [[6, 'x', 4, '=', 24], [75, '-', 24, '=', 51], [2, '+', 51, '=', 53], [7, 'x', 53, '=', 371], [371, '+', 8, '=', 379]]
# [[6, 'x', 4, '=', 24], [24, '-', 2, '=', 22], [75, '-', 22, '=', 53], [7, 'x', 53, '=', 371], [371, '+', 8, '=', 379]]
# [[6, '+', 8, '=', 14], [2, '+', 7, '=', 9], [14, '-', 9, '=', 5], [75, 'x', 5, '=', 375], [4, '+', 375, '=', 379]]
# [[6, '+', 8, '=', 14], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [375, '+', 4, '=', 379]]
# [[6, '+', 8, '=', 14], [14, '-', 2, '=', 12], [12, '-', 7, '=', 5], [75, 'x', 5, '=', 375], [4, '+', 375, '=', 379]]
# [[6, '+', 8, '=', 14], [14, '-', 7, '=', 7], [7, '-', 2, '=', 5], [75, 'x', 5, '=', 375], [4, '+', 375, '=', 379]]
# [[6, 'x', 8, '=', 48], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [375, '+', 4, '=', 379]]
# [[4, '+', 8, '=', 12], [2, '+', 75, '=', 77], [12, '-', 7, '=', 5], [77, 'x', 5, '=', 385], [385, '-', 6, '=', 379]]
# [[4, '+', 8, '=', 12], [6, '-', 2, '=', 4], [12, '-', 7, '=', 5], [75, 'x', 5, '=', 375], [4, '+', 375, '=', 379]]
# [[4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [6, '+', 375, '=', 381], [381, '-', 2, '=', 379]]
# [[4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [6, '-', 2, '=', 4], [375, '+', 4, '=', 379]]
# [[4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [375, '-', 2, '=', 373], [6, '+', 373, '=', 379]]
# [[4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [6, '-', 2, '=', 4], [5, 'x', 75, '=', 375], [375, '+', 4, '=', 379]]
# [[4, '+', 8, '=', 12], [12, '-', 7, '=', 5], [75, '+', 2, '=', 77], [5, 'x', 77, '=', 385], [385, '-', 6, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 7, '=', 14], [14, 'x', 32, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 7, '=', 14], [14, 'x', 32, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 7, '=', 14], [14, 'x', 32, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 7, '=', 14], [75, '-', 6, '=', 69], [14, 'x', 32, '=', 448], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [7, '+', 64, '=', 71], [6, 'x', 75, '=', 450], [450, '-', 71, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [7, 'x', 64, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [7, 'x', 64, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [7, 'x', 64, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [6, 'x', 75, '=', 450], [7, '+', 64, '=', 71], [450, '-', 71, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [6, 'x', 75, '=', 450], [450, '-', 7, '=', 443], [443, '-', 64, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [6, 'x', 75, '=', 450], [450, '-', 64, '=', 386], [386, '-', 7, '=', 379]]
# [[4, 'x', 8, '=', 32], [2, 'x', 32, '=', 64], [75, '-', 6, '=', 69], [7, 'x', 64, '=', 448], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [7, 'x', 32, '=', 224], [2, 'x', 224, '=', 448], [6, '+', 448, '=', 454], [454, '-', 75, '=', 379]]
# [[4, 'x', 8, '=', 32], [7, 'x', 32, '=', 224], [2, 'x', 224, '=', 448], [75, '-', 6, '=', 69], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [7, 'x', 32, '=', 224], [2, 'x', 224, '=', 448], [448, '-', 75, '=', 373], [373, '+', 6, '=', 379]]
# [[4, 'x', 8, '=', 32], [7, 'x', 32, '=', 224], [75, '-', 6, '=', 69], [2, 'x', 224, '=', 448], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [6, 'x', 75, '=', 450], [2, 'x', 32, '=', 64], [7, '+', 64, '=', 71], [450, '-', 71, '=', 379]]
# [[4, 'x', 8, '=', 32], [6, 'x', 75, '=', 450], [2, 'x', 32, '=', 64], [450, '-', 7, '=', 443], [443, '-', 64, '=', 379]]
# [[4, 'x', 8, '=', 32], [6, 'x', 75, '=', 450], [2, 'x', 32, '=', 64], [450, '-', 64, '=', 386], [386, '-', 7, '=', 379]]
# [[4, 'x', 8, '=', 32], [6, 'x', 75, '=', 450], [450, '-', 7, '=', 443], [2, 'x', 32, '=', 64], [443, '-', 64, '=', 379]]
# [[4, 'x', 8, '=', 32], [75, '-', 6, '=', 69], [7, 'x', 2, '=', 14], [14, 'x', 32, '=', 448], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [75, '-', 6, '=', 69], [7, 'x', 32, '=', 224], [2, 'x', 224, '=', 448], [448, '-', 69, '=', 379]]
# [[4, 'x', 8, '=', 32], [75, '-', 6, '=', 69], [2, 'x', 32, '=', 64], [7, 'x', 64, '=', 448], [448, '-', 69, '=', 379]]
# [[8, '-', 2, '=', 6], [6, '+', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 2, '=', 6], [7, '-', 6, '=', 1], [6, '-', 1, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 2, '=', 6], [7, '-', 6, '=', 1], [6, '-', 1, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '/', 2, '=', 4.0], [4.0, '+', 7, '=', 11.0], [11.0, '-', 6, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 2, '=', 4.0], [7, '-', 6, '=', 1], [4.0, '+', 1, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 2, '=', 4.0], [6, '-', 4.0, '=', 2.0], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 2, '=', 4.0], [6, '-', 4, '=', 2], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4.0, '+', 375, '=', 379.0]]
# [[8, '-', 7, '=', 1], [2, '-', 1, '=', 1], [6, '-', 1, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 7, '=', 1], [2, '+', 75, '=', 77], [1, '+', 4, '=', 5], [5, 'x', 77, '=', 385], [385, '-', 6, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 6, '=', 7], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [2, '+', 75, '=', 77], [5, 'x', 77, '=', 385], [385, '-', 6, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [6, '-', 2, '=', 4], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [5, 'x', 75, '=', 375], [6, '-', 2, '=', 4], [4, '+', 375, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [5, 'x', 75, '=', 375], [6, '+', 375, '=', 381], [381, '-', 2, '=', 379]]
# [[8, '-', 7, '=', 1], [1, '+', 4, '=', 5], [5, 'x', 75, '=', 375], [375, '-', 2, '=', 373], [373, '+', 6, '=', 379]]
# [[8, '-', 7, '=', 1], [6, '-', 2, '=', 4], [1, '+', 4, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 7, '=', 1], [6, '-', 1, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 6, '=', 2], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 6, '=', 2], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 4, '=', 4], [2, 'x', 6, '=', 12], [12, '-', 7, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '-', 4, '=', 4], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4, '+', 375, '=', 379]]
# [[8, '/', 4, '=', 2.0], [2, '+', 75, '=', 77], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 77, '=', 385.0], [385.0, '-', 6, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [6, '-', 2.0, '=', 4.0], [4.0, '+', 375, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [6, '+', 375, '=', 381], [381, '-', 2.0, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [375, '-', 2.0, '=', 373.0], [373.0, '+', 6, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2, '=', 5], [6, '-', 2.0, '=', 4.0], [5, 'x', 75, '=', 375], [4.0, '+', 375, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2, '=', 5], [2.0, '+', 75, '=', 77.0], [5, 'x', 77.0, '=', 385.0], [385.0, '-', 6, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [2, '+', 75, '=', 77], [5.0, 'x', 77, '=', 385.0], [385.0, '-', 6, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [6, '-', 2, '=', 4], [5.0, 'x', 75, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [6, '-', 2, '=', 4], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [6, '+', 375.0, '=', 381.0], [381.0, '-', 2, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [375.0, '-', 2, '=', 373.0], [373.0, '+', 6, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [6, '-', 2, '=', 4], [7, '-', 2.0, '=', 5.0], [5.0, 'x', 75, '=', 375.0], [4, '+', 375.0, '=', 379.0]]
# [[8, '/', 4, '=', 2.0], [6, '-', 2.0, '=', 4.0], [7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [4.0, '+', 375, '=', 379.0]]

# %%
#OPTIMAL SEARCH

results = []
lengths = []

def stack_builder(target, node, results, lengths) :
    if target in node.memo :
        results.append(node.track)
        lengths.append(len(node.track))
    for children in node.children :
        stack_builder(target_number, children, results, lengths)

stack_builder(target_number, T.tree, results, lengths)


print('We can use:',draw)
print('We want :',target_number)
print(' ')

if lengths == []:
    print('THERE ARE NO SOLUTION')

optimal_paths = []
if len(lengths) !=0:
    m = min(lengths)
    for path in results :
        if len(path) == m:
            optimal_paths.append(path)
                
    print('THE OPTIMAL SOLUTIONS ARE:')
    for path in optimal_paths:   
        print(path)
        print('----')
# Out:
# We can use: [75, 2, 7, 6, 4, 8]
# We want : 379
#
# THE OPTIMAL SOLUTIONS ARE:
# [[7, '-', 2, '=', 5], [5, 'x', 75, '=', 375], [375, '+', 4, '=', 379]]
# ----

# %%
#TESTS ZONE

print(target_number)
print(draw)
def pre_order(node):
    if node is None:
        return
    print(node.memo, end=' ')
    for children in node.children:
        pre_order(children)
        
pre_order(T.tree)
